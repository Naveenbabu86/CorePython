# %%
#list(mutable)
employees = ["Naveen","Ramu","Somu"]
employees.append("Raju")
employees.extend("Jeevan")
emp1= employees[0]
print(emp1)
employees
employees[0]="Praveen"
employees
# Out:
# Naveen
# ['Praveen', 'Ramu', 'Somu', 'Raju', 'J', 'e', 'e', 'v', 'a', 'n']

# %%
#tuple is immutable once we create it it we can t change , that is why it does not  have the 
# methods like extend and append
employees = ("Naveen","Ramu","Somu")

# %%
# dictionary

emp = {
    "name": "Naveen",
    "empid" : "0123H"

}

# %%
for name,empid  in emp.items():
    print(name,empid)
# Out:
# name Naveen
# empid 0123H

# %%
set1 = {1,2,3,4,5,6,1}
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}
