# %% [markdown]
# # this is comosition
# class Agent:
#
#     def __init__(self):
#         self.llm = GPTModel()
#         self.memory = VectorMemory()
#         self.tool = SearchTool()

# %% [markdown]
# # this is dependency injection

# %%
class Agent:

    def __init__(self,llm,memory,tool):
        self.llm = llm
        self.memory = memory
        self.tool = tool
        
   gpt = GPTModel()
   memory = VectoryMemory()
   tool = SearchTool()

   agent = agent(gpt,memory,toll)
